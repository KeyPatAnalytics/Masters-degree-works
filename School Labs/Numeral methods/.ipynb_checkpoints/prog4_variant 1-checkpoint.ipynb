# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# N_max - максимальное кол-во итераций 
# f - данная функция
# df - производная данной функции; 


def Newton(f, df, x0, tolerance=1e-10, verbose=False, N_max=100):
    ### your solution is here
    error = 100
    i = 0
    while error > tolerance and i < N_max:
        x0 -= f(x0) / df(x0)
        error = abs(f(x0))
        i += 1
        if verbose:
            print(f'Iteration {i}, error = {error:.2}, x = {x0:.8}.')
    return x0

# %%
f = lambda z: z**3 -1
df = lambda z: 3*z**2

Newton(f, df, -3, tolerance=1e-10, verbose=True)
print('\n')
# Out:
# Iteration 1, error = 8.6, x = -1.962963.
# Iteration 2, error = 2.8, x = -1.2221343.
# Iteration 3, error = 1.2, x = -0.59158362.
# Iteration 4, error = 0.83, x = 0.55807031.
# Iteration 5, error = 2.0, x = 1.4423355.
# Iteration 6, error = 0.41, x = 1.1217879.
# Iteration 7, error = 0.039, x = 1.0127435.
# Iteration 8, error = 0.00048, x = 1.0001597.
# Iteration 9, error = 7.6e-08, x = 1.0.
# Iteration 10, error = 2e-15, x = 1.0.

# %%
N = 1000
t = np.linspace(-1, 1, N)
x, y = np.meshgrid(t, t)
x = x.reshape(-1,)
y = y.reshape(-1,)
z = x + 1j*y

points = []
for p in z:
    solution = Newton(f, df, p)
    points.append(solution)
points = np.hstack(points).reshape(N, N)
points = np.real(np.cos(points)*np.sin(np.imag(points)))

fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.imshow(points, cmap='inferno')
ax.axis('off');
